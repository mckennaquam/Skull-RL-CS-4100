# %%
import pandas as pd

# %%
df_random = pd.read_csv("simulation_data/random_skull.csv")

# %%
df_random.groupby('player')['result'].value_counts().reset_index(name='Count')
# Out:
#    player         result  Count
# 0       0  win via score   2382
# 1       0   win via elim     88
# 2       1  win via score   2414
# 3       1   win via elim    116
# 4       2  win via score   2437
# 5       2   win via elim    115
# 6       3  win via score   2338
# 7       3   win via elim    110

# %%
df_mean = pd.read_csv("simulation_data/one_mean_three_random_skull.csv")
df_mean.groupby('player')[['player_type', 'result']].value_counts().reset_index(name='Count')
# Out:
#    player player_type         result  Count
# 0       0        mean   win via elim     70
# 1       1        rand  win via score   3484
# 2       2        rand  win via score   3318
# 3       3        rand  win via score   3128

# %%
df_mean = pd.read_csv("simulation_data/one_nice_three_random_skull.csv")
df_mean.groupby('player')[['player_type', 'result']].value_counts().reset_index(name='Count')
# Out:
#    player player_type         result  Count
# 0       0        nice  win via score   4643
# 1       1        rand  win via score   1652
# 2       1        rand   win via elim    118
# 3       2        rand  win via score   1646
# 4       2        rand   win via elim    109
# 5       3        rand  win via score   1760
# 6       3        rand   win via elim     72

# %%
df_nice_mean = pd.read_csv("simulation_data/one_nice_one_mean_two_random_skull.csv")
df_nice_mean.groupby('player')[['player_type', 'result']].value_counts().reset_index(name='Count')
# Out:
#    player player_type         result  Count
# 0       0        nice  win via score   5073
# 1       1        mean   win via elim     36
# 2       1        mean  win via score      1
# 3       2        rand  win via score   2540
# 4       3        rand  win via score   2350

# %%
df_smart_1 = pd.read_csv("simulation_data/one_smart_three_random_skull.csv")
df_smart_1.groupby('player')[['player_type', 'result']].value_counts().reset_index(name='Count')
# Out:
#    player player_type         result  Count
# 0       0       smart  win via score   3448
# 1       0       smart   win via elim    217
# 2       1        rand  win via score   1967
# 3       1        rand   win via elim    229
# 4       2        rand  win via score   1945
# 5       2        rand   win via elim    123
# 6       3        rand  win via score   1956
# 7       3        rand   win via elim    115

# %%
df_smart_1 = pd.read_csv("simulation_data/one_smart_three_random_skull.csv")
test=  df_smart_1[df_smart_1["player_type"] == "smart"].groupby("result").value_counts().reset_index(name="count")
test[test["result"] == "win via score"]["count"].iloc[0]
# Out:
# np.int64(3448)

# %%
df_smart_2 = pd.read_csv("simulation_data/four_smart.csv")
df_smart_2.groupby('player')[['player_type', 'result']].value_counts().reset_index(name='Count')
# Out:
#    player      player_type         result  Count
# 0       0  smart: 0.5, 0.6  win via score   2266
# 1       0  smart: 0.5, 0.6   win via elim    180
# 2       1  smart: 0.5, 0.6  win via score   2356
# 3       1  smart: 0.5, 0.6   win via elim    165
# 4       2  smart: 0.5, 0.6  win via score   2400
# 5       2  smart: 0.5, 0.6   win via elim    197
# 6       3  smart: 0.5, 0.6  win via score   2274
# 7       3  smart: 0.5, 0.6   win via elim    162

# %%
df_smart2_1 = pd.read_csv("simulation_data/smart2_sf.csv")
df_smart2_1
# Out:
#    Unnamed: 0  skull_factor  raise_thershold  win_count_score  win_count_elim
# 0           0           0.0              0.6           3475.0            87.0
# 1           1           1.0              0.6           4106.0            74.0
# 2           2           2.0              0.6           4319.0            59.0
# 3           3           3.0              0.6           4598.0            45.0

# %%
import matplotlib.pyplot as plt

# %%
player_type = ["Random", "Mean", "Nice", "Smart 1", "Smart 2"]
win_count = [2448, 70, 4643, 5718, 5113]

plt.bar(player_type, win_count, color="#3b528b")

plt.xlabel('Player Type')
plt.ylabel('Count of Wins')
plt.title('Player Type v Random Players')

plt.show()
